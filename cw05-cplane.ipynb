# %%
import cplane as cpl

# %%
xmin = -5.
xmax = 5.
ymin = -5.
ymax = 5.

# %%
thePlane = cpl.ComplexPlane(xmin,xmax,ymin,ymax)

# %%
thePlane.plane
# Out:
# [[(-5-5j),
#   (-5-4.5j),
#   (-5-4j),
#   (-5-3.5j),
#   (-5-3j),
#   (-5-2.5j),
#   (-5-2j),
#   (-5-1.5j),
#   (-5-1j),
#   (-5-0.5j),
#   (-5+0j),
#   (-5+0.5j),
#   (-5+1j),
#   (-5+1.5j),
#   (-5+2j),
#   (-5+2.5j),
#   (-5+3j),
#   (-5+3.5j),
#   (-5+4j),
#   (-5+4.5j)],
#  [(-4.5-5j),
#   (-4.5-4.5j),
#   (-4.5-4j),
#   (-4.5-3.5j),
#   (-4.5-3j),
#   (-4.5-2.5j),
#   (-4.5-2j),
#   (-4.5-1.5j),
#   (-4.5-1j),
#   (-4.5-0.5j),
#   (-4.5+0j),
#   (-4.5+0.5j),
#   (-4.5+1j),
#   (-4.5+1.5j),
#   (-4.5+2j),
#   (-4.5+2.5j),
#   (-4.5+3j),
#   (-4.5+3.5j),
#   (-4.5+4j),
#   (-4.5+4.5j)],
#  [(-4-5j),
#   (-4-4.5j),
#   (-4-4j),
#   (-4-3.5j),
#   (-4-3j),
#   (-4-2.5j),
#   (-4-2j),
#   (-4-1.5j),
#   (-4-1j),
#   (-4-0.5j),
#   (-4+0j),
#   (-4+0.5j),
#   (-4+1j),
#   (-4+1.5j),
#   (-4+2j),
#   (-4+2.5j),
#   (-4+3j),
#   (-4+3.5j),
#   (-4+4j),
#   (-4+4.5j)],
#  [(-3.5-5j),
#   (-3.5-4.5j),
#   (-3.5-4j),
#   (-3.5-3.5j),
#   (-3.5-3j),
#   (-3.5-2.5j),
#   (-3.5-2j),
# ...
